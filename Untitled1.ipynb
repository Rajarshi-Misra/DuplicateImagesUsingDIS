# %%
from DeepImageSearch import Index,LoadData,SearchImage

# %%
image_list = LoadData().from_folder(['Rishabh'])

# %%
Index(image_list).Start()
# Out:
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 74/74 [01:07<00:00,  1.09it/s]
# Image Meta Information Saved: [meta-data-files/image_data_features.pkl]
# 66it [00:00, 1332.47it/s]
# Saved the Indexed File:[meta-data-files/image_features_vectors.ann]

# %%
SearchImage().get_similar_images(image_path=image_list[21],number_of_images=5)
# Out:
# 1/1 [==============================] - 0s 389ms/step
# {15: 'Rishabh\\IMG_2939.CR2',
#  16: 'Rishabh\\IMG_2940.CR2',
#  10: 'Rishabh\\IMG_2934.CR2',
#  5: 'Rishabh\\IMG_2921.CR2',
#  12: 'Rishabh\\IMG_2936.CR2'}

# %%
SearchImage().plot_similar_images(image_path = image_list[21])
# Out:
# 1/1 [==============================] - 0s 328ms/step
